# %%
from kaggle.api.kaggle_api_extended import KaggleApi
import os

# %%
# def descargar_dataset_kaggle():
#     # Parámetros de configuración
#     identificador_dataset = "sgluege/noisy-drone-rf-signal-classification-v2"
#     ruta_destino = r"C:\TFM_data\NoisyUAV"

#     # Creación del directorio si no existe
#     os.makedirs(ruta_destino, exist_ok=True)
#     print(f"Directorio de destino configurado: {ruta_destino}")

#     try:
#         # Inicialización y autenticación de la API
#         api = KaggleApi()
#         api.authenticate()
        
#         print(f"Iniciando descarga del dataset: {identificador_dataset}")
#         print("Este proceso puede tardar dependiendo de su ancho de banda (Aprox. 148 GB)...")
        
#         # Descarga y extracción (unzip=True evita tener que descomprimir manualmente)
#         api.dataset_download_files(
#             dataset=identificador_dataset, 
#             path=ruta_destino, 
#             unzip=True
#         )
        
#         print(f"Proceso finalizado. Datos extraídos en: {ruta_destino}")

#     except Exception as e:
#         print(f"Error de ejecución: {e}")
#         print("Verifique la existencia y ubicación del archivo kaggle.json en su directorio de usuario.")

# # Ejecución del bloque
# if __name__ == "__main__":
#     descargar_dataset_kaggle()
# Out:
# Directorio de destino configurado: C:\TFM_data\NoisyUAV
# Iniciando descarga del dataset: sgluege/noisy-drone-rf-signal-classification-v2
# Este proceso puede tardar dependiendo de su ancho de banda (Aprox. 148 GB)...
# Dataset URL: https://www.kaggle.com/datasets/sgluege/noisy-drone-rf-signal-classification-v2
